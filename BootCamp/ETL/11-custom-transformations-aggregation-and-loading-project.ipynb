# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="../../resources/logo.png" alt="Intellinum Bootcamp" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # Capstone Project: Custom Transformations, Aggregating and Loading
#
# The goal of this project is to populate aggregate tables using Twitter data.  In the process, you write custom User Defined Functions (UDFs), aggregate daily most trafficked domains, join new records to a lookup table, and load to a target database.
#
#
# ## Instructions
#
# The Capstone work for the previous course in this series (ETL: Part 1) defined a schema and created tables to populate a relational mode. In this capstone project you take the project further.
#
# In this project you ETL JSON Twitter data to build aggregate tables that monitor trending websites and hashtags and filter malicious users using historical data.  Use these four exercises to achieve this goal:<br><br>
#
# 1. **Parse tweeted URLs** using a custom UDF
# 2. **Compute aggregate statistics** of most tweeted websites and hashtags by day
# 3. **Join new data** to an existing dataset of malicious users
# 4. **Load records** into a target database

# %% [markdown]
# Run the following cell to create the lab environment:

# %%
#MODE = "LOCAL"
MODE = "CLUSTER"

import sys
from pyspark.sql import SparkSession
from pyspark import SparkConf
import os
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark import SparkConf
from pyspark.sql.types import *
from pyspark.sql import functions as F
from pyspark.storagelevel import StorageLevel
from matplotlib import interactive
interactive(True)
import matplotlib.pyplot as plt
# %matplotlib inline
import json
import math
import numbers
import numpy as np
import plotly
plotly.offline.init_notebook_mode(connected=True)

sys.path.insert(0,'../../src')
from settings import *

try:
    fh = open('../../libs/pyspark24_py36.zip', 'r')
except FileNotFoundError:
    # !aws s3 cp s3://devops.intellinum.co/bins/pyspark24_py36.zip ../../libs/pyspark24_py36.zip

try:
    spark.stop()
    print("Stopped a SparkSession")
except Exception as e:
    print("No existing SparkSession detected")
    print("Creating a new SparkSession")

SPARK_DRIVER_MEMORY= "1G"
SPARK_DRIVER_CORE = "1"
SPARK_EXECUTOR_MEMORY= "1G"
SPARK_EXECUTOR_CORE = "1"
SPARK_EXECUTOR_INSTANCES = 12



conf = None
if MODE == "LOCAL":
    os.environ["PYSPARK_PYTHON"] = "/home/yuan/anaconda3/envs/pyspark24_py36/bin/python"
    conf = SparkConf().\
            setAppName("pyspark_etl_11-custom-etl-project").\
            setMaster('local[*]').\
            set('spark.driver.maxResultSize', '0').\
            set('spark.jars', '../../libs/mysql-connector-java-5.1.45-bin.jar').\
            set('spark.jars.packages','net.java.dev.jets3t:jets3t:0.9.0,com.google.guava:guava:16.0.1')
else:
    os.environ["PYSPARK_PYTHON"] = "./MN/pyspark24_py36/bin/python"
    conf = SparkConf().\
            setAppName("pyspark_etl_11-custom-etl-project-database-writes-rj").\
            setMaster('yarn-client').\
            set('spark.executor.cores', SPARK_EXECUTOR_CORE).\
            set('spark.executor.memory', SPARK_EXECUTOR_MEMORY).\
            set('spark.driver.cores', SPARK_DRIVER_CORE).\
            set('spark.driver.memory', SPARK_DRIVER_MEMORY).\
            set("spark.executor.instances", SPARK_EXECUTOR_INSTANCES).\
            set('spark.sql.files.ignoreCorruptFiles', 'true').\
            set('spark.yarn.dist.archives', '../../libs/pyspark24_py36.zip#MN').\
            set('spark.driver.maxResultSize', '0').\
            set('spark.jars.packages','net.java.dev.jets3t:jets3t:0.9.0,com.google.guava:guava:16.0.1'). \
            set('spark.driver.maxResultSize', '0').\
            set('spark.jars', 's3://devops.intellinum.co/bins/mysql-connector-java-5.1.45-bin.jar')
        

spark = SparkSession.builder.\
    config(conf=conf).\
    getOrCreate()


sc = spark.sparkContext

sc.addPyFile('../../src/settings.py')

sc=spark.sparkContext
hadoop_conf = sc._jsc.hadoopConfiguration()
hadoop_conf.set("fs.s3.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
hadoop_conf.set("mapreduce.fileoutputcommitter.algorithm.version", "2")

def display(df, limit=10):
    return df.limit(limit).toPandas()

def dfTest(id, expected, result):
    assert str(expected) == str(result), "{} does not equal expected {}".format(result, expected)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# No existing SparkSession detected
# Creating a new SparkSession

# %% [markdown]
# ## Exercise 1: Parse Tweeted URLs
#
# Some tweets in the dataset contain links to other websites.  Import and explore the dataset using the provided schema.  Then, parse the domain name from these URLs using a custom UDF.

# %% [markdown]
# ### Step 1: Import and Explore
#
# The following is the schema created as part of the capstone project for ETL Part 1.
# Run the following cell and then use this schema to import one file of the Twitter data.

# %%
from pyspark.sql.types import StructField, StructType, ArrayType, StringType, IntegerType, LongType
from pyspark.sql.functions import col

fullTweetSchema = StructType([
  StructField("id", LongType(), True),
  StructField("user", StructType([
    StructField("id", LongType(), True),
    StructField("screen_name", StringType(), True),
    StructField("location", StringType(), True),
    StructField("friends_count", IntegerType(), True),
    StructField("followers_count", IntegerType(), True),
    StructField("description", StringType(), True)
  ]), True),
  StructField("entities", StructType([
    StructField("hashtags", ArrayType(
      StructType([
        StructField("text", StringType(), True)
      ]),
    ), True),
    StructField("urls", ArrayType(
      StructType([
        StructField("url", StringType(), True),
        StructField("expanded_url", StringType(), True),
        StructField("display_url", StringType(), True)
      ]),
    ), True)
  ]), True),
  StructField("lang", StringType(), True),
  StructField("text", StringType(), True),
  StructField("created_at", StringType(), True)
])

# %% [markdown]
# Import one file of the JSON data located at `s3a://data.intellinum.co/bootcamp/common/twitter/firehose/2018/01/08/18/twitterstream-1-2018-01-08-18-48-00-bcf3d615-9c04-44ec-aac9-25f966490aa4` using the schema.  Be sure to do the following:<br><br>
#
# * Save the result to `tweetDF`
# * Apply the schema `fullTweetSchema`
# * Filter out null values from the `id` column

# %%
# TODO
path = "s3a://data.intellinum.co/bootcamp/common/twitter/firehose/2018/01/08/18/twitterstream-1-2018-01-08-18-48-00-bcf3d615-9c04-44ec-aac9-25f966490aa4"
tweetDF = spark.read.schema(fullTweetSchema).json(path).dropna('any', subset=['id'])

# %%
display(tweetDF, 100)
# Out:
#                     id                                               user  \
# 0   950438954272096257  (371607576, smileifyou_love, None, 473, 160, •...
# 1   950438954288914432  (732417055, bw198e18, None, 1641, 1285, 【期間限定】...
# 2   950438954276450305    (235927210, marlascigarette, None, 214, 223, △)
# 3   950438954280472576       (1564880654, rebaab_1326, None, 45, 0, None)
# 4   950438954288889856  (349070364, puskine, Kampala, Uganda, 5008, 49...
# 5   950438954280669184  (340482488, xNina_Beana, the land , 1130, 1646...
# 6   950438954276442113  (4354072997, gbfranca22, cpx da congo🔞, 252, 6...
# 7   950438954276478976  (738897225061912576, squeeqi, None, 213, 160, ...
# 8   950438954289033216          (273646363, iiib53, None, 631, 427, None)
# 9   950438954289033218     (1541143441, nappo_what, 🇫🇮🇺🇦, 297, 925, None)
# 10  950438954297303040  (2937433261, zooeeen, None, 220, 3165, ✨🧚🏽‍♀️ ...
# 11  950438954297274368  (3318213908, vickydxblas, followed by Shawn Me...
# 12  950438954272215041    (2296919349, mirkoasuarezm, None, 23, 44, None)
# 13  950438954297208832  (766017625495314433, HctorNol3, Durango, Méxic...
# 14  950438954297249792  (948483890468958208, Astel_SWG, 오늘도 부디 무사히 다녀오...
# 15  950438954276409346     (2395396997, preetinhaeu, None, 99, 313, None)
# 16  950438954301472768   (2791365483, hamtorihyodorie, 태국, 236, 88, None)
# 17  950438954284797958  (3243825293, kersplats, rio de janeiro, 762, 6...
# 18  950438954301579265  (948709436570382336, felixcantillo, None, 259,...
# 19  950438954288984064  (893053271245549568, mangootaktk, None, 2086, ...
# 20  950438954297450497  (941196347486752769, figendinceralr1, None, 33...
# 21  950438954305716226  (1438498315, HFC_56_k, None, 305, 250, هلالي ....
# 22  950438954276356098  (300784082, laurenpedia, Motonui, 277, 983, re...
# 23  950438954310033410  (913092712282431491, Mem_Alive, Dallas, TX, 37...
# 24  950438954272284674  (2598221366, hoor197, None, 2629, 1969, ‏أبي -...
# 25  950438954305835008  (222034168, RIGB2266, The Universe, 380, 638, ...
# 26  950438954272256001  (2393173160, BenLeggiero, Georgia, US, 290, 40...
# 27  950438954305761280  (3944319021, mannydidthisone, Cleveland, 89, 5...
# 28  950438954301616128  (303581436, That_Hourglass, La-La-Land ♪ ♫ ♩ ♬...
# 29  950438954289025024  (338583130, katelynndragon, 309, 396, 411, my ...
# ..                 ...                                                ...
# 70  950438958495928320  (783953695570530305, Aueee77, الرياض, 1455, 92...
# 71  950438958483337217  (1130905266, Hedi_Nho,  Paris, 301, 171, Jamai...
# 72  950438958495879168  (1327964071, _feellng, None, 300, 1245, fallin...
# 73  950438958466584576  (94060231, AkiSizuha, 守屋神社, 16136, 19178, 二つ名「...
# 74  950438958466465792  (913923956763176960, skystar6325, None, 56, 5,...
# 75  950438958487560196  (837813045824995328, KathlenSantos_, São josé ...
# 76  950438958474977281  (939925054896398337, Atelis_symfonia, None, 19...
# 77  950438958474948613  (4710495552, Fernando_RomanQ, Durango, México,...
# 78  950438958504271873  (2890628335, lanm_13, None, 1624, 1048, ‏انا ا...
# 79  950438958487494658  (4127290403, selcuk1299, ankara, 175, 271, #Si...
# 80  950438958487474181  (912826254386229248, LaurMila13, None, 127, 15...
# 81  950438958474911744  (842079559969320971, reno_ales10, None, 545, 7...
# 82  950438958495944707  (878707111596875776, ootirevivaI, i am so grat...
# 83  950438958487494657  (1262522527, SvenchuSemao, Yutubi, 292, 825, M...
# 84  950438958478995456         (4849973375, sping_ds, None, 174, 3, None)
# 85  950438958491631616  (881898023491653633, sultann2522, None, 239, 1...
# 86  950438958466588672  (765701017031892993, DieDieDieReyes, None, 500...
# 87  950438958466502656  (3167538797, RyDaisha_, Athens, GA, 171, 636, ...
# 88  950438958470660096  (870322754112942080, _inesmreis, Portugal, 382...
# 89  950438958470713346  (733641904030679040, francinemazala, None, 52,...
# 90  950438958495879169  (32598227, stlbf, St. Charles, MO, 314, 112, S...
# 91  950438958466588673  (2211355508, Fernandezfeedee, None, 306, 388, ...
# 92  950438958487560194  (824389184, CooolStufff, None, 66563, 91661, I...
# 93  950438958504267777  (64028483, JarmarDupas, Houston, Texas, 288, 4...
# 94  950438958495944705  (744673274, elbernabeucom, Madrid, 470, 82842,...
# 95  950438958474977280  (892897899104927744, AtelierTrends, None, 42, ...
# 96  950438958479171585  (35770090, zel__b, Traveling Across the 🌎🌍🌏, 3...
# 97  950438958483124225  (944526300957392899, mar2min, 渋谷は俺の庭？, 46, 34,...
# 98  950438962660716544  (2297478635, _pprathanaCr, None, 267, 232, มอง...
# 99  950438962677641217  (86180957, _D_Woods_,   Memphis/ Nashville, 75...
#
#                                              entities lang  \
# 0                                            ([], [])   en
# 1                                     ([(diet,)], [])   ja
# 2                                            ([], [])   tr
# 3   ([(صاروخ_سعودي_يرعب_ايران,)], [(https://t.co/j...   ar
# 4                                            ([], [])   en
# 5                                            ([], [])   en
# 6                                            ([], [])   pt
# 7                                            ([], [])   en
# 8                                            ([], [])   ar
# 9                                            ([], [])   ru
# 10                    ([(Tea,), (GoldenGlobes,)], [])   en
# 11                                           ([], [])   en
# 12                                           ([], [])   es
# 13                                           ([], [])   en
# 14                                           ([], [])   ko
# 15                                           ([], [])   pt
# 16                                           ([], [])   ko
# 17  ([], [(https://t.co/B5Zgkoy4TL, https://twitte...   en
# 18                                           ([], [])   es
# 19                                           ([], [])  und
# 20                                           ([], [])   tr
# 21                          ([(الهلال_الاتفاق,)], [])   ar
# 22                                           ([], [])   pt
# 23  ([], [(http://t.co/Kv3EWEhO, http://bit.ly/OYl...   en
# 24                                           ([], [])   ar
# 25  ([], [(https://t.co/l3x0sVSvFa, https://goo.gl...   en
# 26                                           ([], [])   es
# 27  ([(beats,), (90s,), (90shiphop,), (pac,), (leg...   en
# 28                                           ([], [])   en
# 29                                           ([], [])  und
# ..                                                ...  ...
# 70                                           ([], [])   ar
# 71                                           ([], [])   fr
# 72                                           ([], [])   en
# 73                                           ([], [])   ja
# 74                                           ([], [])   en
# 75                                           ([], [])   pt
# 76                                           ([], [])   el
# 77                     ([(CredencialParaVotar,)], [])   es
# 78  ([], [(https://t.co/zym0XMIzSs, http://du3a.or...   ar
# 79  ([], [(https://t.co/2enH654iIr, https://twitte...   tr
# 80                                           ([], [])   es
# 81                                           ([], [])   ar
# 82                                           ([], [])   en
# 83  ([], [(https://t.co/48Z78TrYJO, https://twitte...   es
# 84  ([(GOT7,), (Got7เป็นวงตลก,), (BamBam,), (Jacks...   th
# 85                                           ([], [])   ar
# 86                                           ([], [])   en
# 87                                           ([], [])   en
# 88                                           ([], [])   en
# 89  ([], [(https://t.co/Byu0qaDvKi, https://twitte...   en
# 90  ([], [(https://t.co/8z6pqiYYFV, http://a.pgtb....   en
# 91                                           ([], [])   es
# 92  ([], [(https://t.co/GHT3oQbaFZ, https://vine.c...   en
# 93  ([], [(https://t.co/zjqqlZZ3Fe, https://twitte...   en
# 94  ([(ÚLTIMAHORA,)], [(https://t.co/UZl9W15iD6, h...   es
# 95  ([], [(https://t.co/2ORvC7cGYd, http://pianofo...   en
# 96                                           ([], [])  und
# 97                                           ([], [])   ja
# 98                         ([(บีทูบีเป็นวงตลก,)], [])   th
# 99                                           ([], [])   en
#
#                                                  text  \
# 0   RT @TheTinaVasquez: Quick facts for the know-n...
# 1   【太ももを引きしめるエクササイズ】足あげ～１．うつぶせに寝る。２．片方の足先を床から10セン...
# 2   Ben bir beni bulup icine girip saklanirsam kim...
# 3   تواصل قالوا عن قطر المتحدث باسم الجيش الصهيوني...
# 4   *Before you argue about your dirty house someo...
# 5   RT @TippyLexx: Bruh you ever accidentally open...
# 6   RT @MorraoTudo2: A liberdade é só questão de t...
# 7                     I just want this all to be over
# 8   RT @Arab_original: للاسف قطاع كان ممكن حل ولا ...
# 9   RT @craneswordboi: блять мне так смешно от сло...
# 10  RT @oscahhhhh: THE MOMENT NATALIE PORTMAN SNAP...
# 11  RT @troyesivan: ❤ 'MY MY MY!' OFFICIAL ARTWORK...
# 12  @Capital967 @ADiezGol @diegoreba @cokigonzales...
# 13  RT @KitoriJP: The evolution of Knuckles. https...
# 14  @KAYA_SWG @VNT_SWG @lento_SWG 졸려서 그런겁니다, 카야. 얼...
# 15  to com muita saudade do gustavo cara, nossa\nn...
# 16  RT @bbbbkim: 냄비받침 (편백) .. https://t.co/bTMQIjjTnL
# 17  you make me un poco loco, un poquititito loco\...
# 18                   @zonacero Jummm. Me huele a humo
# 19          RT @DatAzzPhatAF: https://t.co/Ccg78SZLNx
# 20                       MUSTAFA KEMAL ATATÜRKİYE ...
# 21    لازم يقتنع ان العرضيات ما تنفع  #الهلال_الاتفاق
# 22  RT @iloveputarias: ter intimidade pra falar so...
# 23  RT @Alzheimers: Seniors, Try these Exercises! ...
# 24  الكلمات تشبه المفاتيح إذا استخدمتها بشكل صحيح؛...
# 25  Nanoparticles have potential vs cancer - The M...
# 26  iPhone X = "iPhone Ten"\nOS X = "O.S. Ten"\nFi...
# 27  Dropping @ 3. \n\n#beats #90s #90shiphop #pac ...
# 28  RT @sopharush: God,\n\nAllow me to lead with b...
# 29                                                  😒
# ..                                                ...
# 70                                 حبيبي جحفلي والله💙
# 71  RT @FirstDownFR: Il y a 7 ans aujourd'hui, Mar...
# 72                         it sooo fucking hot omigod
# 73                        @Miyowx お疲れさま、頑張りすぎないでくださいね
# 74   @yoonminskit Why was I holding my breath tho😂😂😂😂
# 75                          Sexta sua linda cadê você
# 76  RT @Ch_Aris_: μου λέει ένας παλιός φίλος, από ...
# 77  ¿Cumples 18 años antes del 1° de julio? ¡Trami...
# 78  (قد كانت آياتي تتلى عليكم فكنتم على أعقابكم تن...
# 79  Yıllardır görmediniz görmezden geldiniz. Bir k...
# 80                             @Camila_Cabello Te amo
# 81     RT @__wa7eed: ان شاء الله يصفر الحكم قبل الفجر
# 82  RT @MerleDandridge: One of the greatest nights...
# 83  @10roxas La última versión del parche disponib...
# 84  RT @Aummiiiiiiiii: โอ้ยกูขำเด้อ5555555++ เฮียค...
# 85  RT @dugailbi: "إعلان منحط أخلاقياً"، "إعلان رخ...
# 86  RT @IntimateSiren: Hey! Leah here. I'm sure yo...
# 87                 @Future_Star8 😂😂😂😂 no even stevens
# 88  RT @VlNCHY: after 10 years i finally realized ...
# 89   This is a difficult task https://t.co/Byu0qaDvKi
# 90  I voted for a kids charity to win a donation f...
# 91  RT @nicosalem1: Vayan por todo. Boca y ustedes...
# 92      Can you name this car https://t.co/GHT3oQbaFZ
# 93  It’s MOOOOONDAY!!!!  Episode 77 we discuss The...
# 94  🔴 #ÚLTIMAHORA | Mensaje de Cristiano a los mad...
# 95  Now ANYONE Can Learn Piano or Keyboard / https...
# 96                 @baeciana  https://t.co/TN6Os6QPoP
# 97                       ぁあああ https://t.co/dokBkWXe6t
# 98  RT @stitch_pololo: เมื่อบีทูบีรับรางวัล ส่งต่อ...
# 99  RT @Just1lickbaby: When you try to talk to a g...
#
#                         created_at
# 0   Mon Jan 08 18:47:59 +0000 2018
# 1   Mon Jan 08 18:47:59 +0000 2018
# 2   Mon Jan 08 18:47:59 +0000 2018
# 3   Mon Jan 08 18:47:59 +0000 2018
# 4   Mon Jan 08 18:47:59 +0000 2018
# 5   Mon Jan 08 18:47:59 +0000 2018
# 6   Mon Jan 08 18:47:59 +0000 2018
# 7   Mon Jan 08 18:47:59 +0000 2018
# 8   Mon Jan 08 18:47:59 +0000 2018
# 9   Mon Jan 08 18:47:59 +0000 2018
# 10  Mon Jan 08 18:47:59 +0000 2018
# 11  Mon Jan 08 18:47:59 +0000 2018
# 12  Mon Jan 08 18:47:59 +0000 2018
# 13  Mon Jan 08 18:47:59 +0000 2018
# 14  Mon Jan 08 18:47:59 +0000 2018
# 15  Mon Jan 08 18:47:59 +0000 2018
# 16  Mon Jan 08 18:47:59 +0000 2018
# 17  Mon Jan 08 18:47:59 +0000 2018
# 18  Mon Jan 08 18:47:59 +0000 2018
# 19  Mon Jan 08 18:47:59 +0000 2018
# 20  Mon Jan 08 18:47:59 +0000 2018
# 21  Mon Jan 08 18:47:59 +0000 2018
# 22  Mon Jan 08 18:47:59 +0000 2018
# 23  Mon Jan 08 18:47:59 +0000 2018
# 24  Mon Jan 08 18:47:59 +0000 2018
# 25  Mon Jan 08 18:47:59 +0000 2018
# 26  Mon Jan 08 18:47:59 +0000 2018
# 27  Mon Jan 08 18:47:59 +0000 2018
# 28  Mon Jan 08 18:47:59 +0000 2018
# 29  Mon Jan 08 18:47:59 +0000 2018
# ..                             ...
# 70  Mon Jan 08 18:48:00 +0000 2018
# 71  Mon Jan 08 18:48:00 +0000 2018
# 72  Mon Jan 08 18:48:00 +0000 2018
# 73  Mon Jan 08 18:48:00 +0000 2018
# 74  Mon Jan 08 18:48:00 +0000 2018
# 75  Mon Jan 08 18:48:00 +0000 2018
# 76  Mon Jan 08 18:48:00 +0000 2018
# 77  Mon Jan 08 18:48:00 +0000 2018
# 78  Mon Jan 08 18:48:00 +0000 2018
# 79  Mon Jan 08 18:48:00 +0000 2018
# 80  Mon Jan 08 18:48:00 +0000 2018
# 81  Mon Jan 08 18:48:00 +0000 2018
# 82  Mon Jan 08 18:48:00 +0000 2018
# 83  Mon Jan 08 18:48:00 +0000 2018
# 84  Mon Jan 08 18:48:00 +0000 2018
# 85  Mon Jan 08 18:48:00 +0000 2018
# 86  Mon Jan 08 18:48:00 +0000 2018
# 87  Mon Jan 08 18:48:00 +0000 2018
# 88  Mon Jan 08 18:48:00 +0000 2018
# 89  Mon Jan 08 18:48:00 +0000 2018
# 90  Mon Jan 08 18:48:00 +0000 2018
# 91  Mon Jan 08 18:48:00 +0000 2018
# 92  Mon Jan 08 18:48:00 +0000 2018
# 93  Mon Jan 08 18:48:00 +0000 2018
# 94  Mon Jan 08 18:48:00 +0000 2018
# 95  Mon Jan 08 18:48:00 +0000 2018
# 96  Mon Jan 08 18:48:00 +0000 2018
# 97  Mon Jan 08 18:48:00 +0000 2018
# 98  Mon Jan 08 18:48:01 +0000 2018
# 99  Mon Jan 08 18:48:01 +0000 2018
#
# [100 rows x 6 columns]

# %%
# TEST - Run this cell to test your solution
dfTest("ET2-P-08-01-01", 1491, tweetDF.count())
dfTest("ET2-P-08-01-02", True, "text" in tweetDF.columns and "id" in tweetDF.columns)

print("Tests passed!")
# Out:
# Tests passed!

# %% [markdown]
# ### Step 2: Write a UDF to Parse URLs
#
# The Python regular expression library `re` allows you to define a set of rules of a string you want to match. In this case, parse just the domain name in the string for the URL of a link in a Tweet. Take a look at the following example:
#
# ```
# import re
#
# URL = "https://spark.apache.org/"
# pattern = re.compile(r"https?://(www\.)?([^/#?]+).*$")
# match = pattern.search(URL)
# print("The string {} matched {}".format(URL, match.group(2)))
# ```
#
# This code prints `The string https://spark.apache.org/ matched spark.apache.org`. **Wrap this code into a function named `getDomain` that takes a parameter `URL` and returns the matched string.**
#
# <a href="https://docs.python.org/3/howto/regex.html" target="_blank">You can find more on the `re` library here.</a>

# %%
# TODO
import re

def getDomain(URL):
    pattern = re.compile(r"https?://(www\.)?([^/#?]+).*$")
    match = pattern.search(URL)
    print("The string {} matched {} ".format(URL, match.group(2)))
    return match.group(2)

getDomain("https://t.co/2enH654iIr")
getDomain("https://spark.apache.org/")
getDomain("https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html")
# Out:
# The string https://t.co/2enH654iIr matched t.co
# The string https://spark.apache.org/ matched spark.apache.org
# The string https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html matched docs.conda.io
# 'docs.conda.io'

# %%
# TEST - Run this cell to test your solution
dfTest("ET2-P-08-02-01", "spark.apache.org",  getDomain("https://spark.apache.org/"))

print("Tests passed!")
# Out:
# The string https://spark.apache.org/ matched spark.apache.org
# Tests passed!

# %% [markdown]
# ### Step 3: Test and Register the UDF
#
# Now that the function works with a single URL, confirm that it works on different URL formats.

# %%
# TEST - Run this cell to test your solution
dfTest("ET2-P-08-02-02", "intellinum.co",  getDomain("https://www.intellinum.co/"))
dfTest("ET2-P-08-02-02", "dzone.com",  getDomain("https://dzone.com/articles/spark-streaming-vs-structured-streaming"))
dfTest("ET2-P-08-02-02", "docs.conda.io",  getDomain("https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html"))
dfTest("ET2-P-08-02-02", "datacamp.com",  getDomain("https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python"))
dfTest("ET2-P-08-02-02", "spark.apache.org",  getDomain("https://spark.apache.org/docs/2.4.0/sql-pyspark-pandas-with-arrow.html"))
dfTest("ET2-P-08-02-02", "apache.org",  getDomain("http://www.apache.org/"))

print("Tests passed!")
# Out:
# The string https://www.intellinum.co/ matched intellinum.co
# The string https://dzone.com/articles/spark-streaming-vs-structured-streaming matched dzone.com
# The string https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html matched docs.conda.io
# The string https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python matched datacamp.com
# The string https://spark.apache.org/docs/2.4.0/sql-pyspark-pandas-with-arrow.html matched spark.apache.org
# The string http://www.apache.org/ matched apache.org
# Tests passed!

# %% [markdown]
# Register the UDF as `getDomainUDF`.

# %%
from pyspark.sql.types import StringType

getDomainUDF = spark.udf.register('getDomainUDFSQL', getDomain, StringType())

# %% [markdown]
# Run the following cell to test your function further.

# %%
# TEST - Run this cell to test your solution
dfTest("ET2-P-08-03-01", True, bool(getDomainUDF))

print("Tests passed!")
# Out:
# Tests passed!

# %% [markdown]
# ### Step 4: Apply the UDF
#
# Create a dataframe called `urlDF` that has three columns:<br><br>
#
# 1. `URL`: The URL's from `tweetDF` (located in `entities.urls.expanded_url`)
# 2. `parsedURL`: The UDF applied to the column `URL`
# 3. `created_at`
#
# There can be zero, one, or many URLs in any tweet.  For this step, use the `explode` function, which takes an array like URLs and returns one row for each value in the array.
# <a href="http://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=explode#pyspark.sql.functions.explode" target="_blank">See the documents here for details.</a>

# %%
urlSchema = StructType([
    StructField("id", LongType(), True),
    StructField('entities', StructType([
        StructField('urls', ArrayType(
            StructType([
                StructField('display_url', StringType(), True),
                StructField('expanded_url', StringType(), True),
                StructField('url', StringType(), True)
            ])), True)
    ])),
    StructField("created_at", StringType(), True)
])

# %%
urlDFPath = "s3a://data.intellinum.co/bootcamp/common/twitter/firehose/2018/01/08/18/twitterstream-1-2018-01-08-18-48-00-bcf3d615-9c04-44ec-aac9-25f966490aa4"
urlTempDF = spark.read.schema(urlSchema).json(urlDFPath).dropna('any', subset=['id']).drop('id')

# %%
display(urlTempDF)
# Out:
#                                             entities  \
# 0                                              ([],)
# 1                                              ([],)
# 2                                              ([],)
# 3  ([(youtube.com/watch?v=b4iz9n…, https://www.yo...
# 4                                              ([],)
# 5                                              ([],)
# 6                                              ([],)
# 7                                              ([],)
# 8                                              ([],)
# 9                                              ([],)
#
#                        created_at
# 0  Mon Jan 08 18:47:59 +0000 2018
# 1  Mon Jan 08 18:47:59 +0000 2018
# 2  Mon Jan 08 18:47:59 +0000 2018
# 3  Mon Jan 08 18:47:59 +0000 2018
# 4  Mon Jan 08 18:47:59 +0000 2018
# 5  Mon Jan 08 18:47:59 +0000 2018
# 6  Mon Jan 08 18:47:59 +0000 2018
# 7  Mon Jan 08 18:47:59 +0000 2018
# 8  Mon Jan 08 18:47:59 +0000 2018
# 9  Mon Jan 08 18:47:59 +0000 2018

# %%
# TODO
urldf = urlTempDF.select(
      F.explode(('entities.urls')).alias('element')
    , F.col('element.expanded_url').alias('URL')
    , F.col('created_at')
).drop('element')

urlDF = urldf.withColumn('parsedURL', getDomainUDF(urldf.URL))
display(urlDF)
# Out:
#                                                  URL  \
# 0        https://www.youtube.com/watch?v=b4iz9nZPzAA
# 1  https://twitter.com/i/web/status/9504389542847...
# 2                               http://bit.ly/OYlKII
# 3                           https://goo.gl/fb/atjACB
# 4           https://www.instagram.com/p/BdsvNFABXNL/
# 5  https://twitter.com/i/web/status/9504389543016...
# 6                                http://alathkar.org
# 7  https://open.spotify.com/album/60eldei5NAr7QjP...
# 8  https://twitter.com/i/web/status/9504389543016...
# 9  https://twitter.com/frann_frann_/status/949080...
#
#                        created_at         parsedURL
# 0  Mon Jan 08 18:47:59 +0000 2018       youtube.com
# 1  Mon Jan 08 18:47:59 +0000 2018       twitter.com
# 2  Mon Jan 08 18:47:59 +0000 2018            bit.ly
# 3  Mon Jan 08 18:47:59 +0000 2018            goo.gl
# 4  Mon Jan 08 18:47:59 +0000 2018     instagram.com
# 5  Mon Jan 08 18:47:59 +0000 2018       twitter.com
# 6  Mon Jan 08 18:47:59 +0000 2018      alathkar.org
# 7  Mon Jan 08 18:47:59 +0000 2018  open.spotify.com
# 8  Mon Jan 08 18:47:59 +0000 2018       twitter.com
# 9  Mon Jan 08 18:47:59 +0000 2018       twitter.com

# %%
# TEST - Run this cell to test your solution
cols = urlDF.columns
sample = urlDF.first()

dfTest("ET2-P-08-04-01", True, "URL" in cols and "parsedURL" in cols and "created_at" in cols)
dfTest("ET2-P-08-04-02", "https://www.youtube.com/watch?v=b4iz9nZPzAA", sample["URL"])
dfTest("ET2-P-08-04-03", "Mon Jan 08 18:47:59 +0000 2018", sample["created_at"])
dfTest("ET2-P-08-04-04", "youtube.com", sample["parsedURL"])

print("Tests passed!")
# Out:
# Tests passed!

# %% [markdown]
# ## Exercise 2: Compute Aggregate Statistics
#
# Calculate top trending 10 URLs by hour.

# %% [markdown]
# ### Step 1: Parse the Timestamp
#
# Create a DataFrame `urlWithTimestampDF` that includes the following columns:<br><br>
#
# * `URL`
# * `parsedURL`
# * `timestamp`
# * `hour`
#
# Import `unix_timestamp` and `hour` from the `functions` module and `TimestampType` from the types `module`. To parse the `create_at` field, use `unix_timestamp` with the format `EEE MMM dd HH:mm:ss ZZZZZ yyyy`.

# %%
# TODO
from pyspark.sql.types import TimestampType

urlWithTimestampTempDF = urlDF.select(
     F.col('URL')
    ,F.col('parsedURL')
    ,F.unix_timestamp(F.col('created_at'), 'EEE MMM dd HH:mm:ss ZZZZZ yyyy').cast(TimestampType()).alias("timestamp")
)

urlWithTimestampDF = urlWithTimestampTempDF.withColumn('hour', F.hour('timestamp'))

# %%
display(urlWithTimestampDF, 100)
# Out:
#                                                   URL  \
# 0         https://www.youtube.com/watch?v=b4iz9nZPzAA
# 1   https://twitter.com/i/web/status/9504389542847...
# 2                                http://bit.ly/OYlKII
# 3                            https://goo.gl/fb/atjACB
# 4            https://www.instagram.com/p/BdsvNFABXNL/
# 5   https://twitter.com/i/web/status/9504389543016...
# 6                                 http://alathkar.org
# 7   https://open.spotify.com/album/60eldei5NAr7QjP...
# 8   https://twitter.com/i/web/status/9504389543016...
# 9   https://twitter.com/frann_frann_/status/949080...
# 10  https://twitter.com/thisisinsider/status/95039...
# 11                               http://goo.gl/TU8gBa
# 12  https://twitter.com/i/web/status/9504389584705...
# 13                                  https://du3a.org/
# 14                         http://whounfollowedme.org
# 15                              https://goo.gl/RgE1Vz
# 16                                    http://du3a.org
# 17  https://twitter.com/i/web/status/9504389584874...
# 18  https://twitter.com/i/web/status/9504389584874...
# 19  https://twitter.com/edward_mwale/status/950221...
# 20                      http://a.pgtb.me/l0JjmW/ncJG5
# 21                      https://vine.co/v/O7qbhaKnLIO
# 22  https://twitter.com/i/web/status/9504389585042...
# 23                    http://ww.elbernabeu.com/Q9P5tC
# 24                http://pianoforalltips.blogspot.com
# 25  http://www.fashionglamtrends.com/now-anyone-ca...
# 26                        http://tinyurl.com/ycc6je3d
# 27  https://twitter.com/i/web/status/9504389626776...
# 28                                   http://du3a.org/
# 29                                    http://du3a.org
# ..                                                ...
# 70  https://twitter.com/naosejatrouxa/status/95043...
# 71  https://twitter.com/i/web/status/9504394576012...
# 72  https://twitter.com/i/web/status/9504394576012...
# 73  https://twitter.com/messages/2310261637-707578...
# 74                              http://dlvr.it/Q9NyHm
# 75  https://twitter.com/i/web/status/9504394617997...
# 76                             https://fb.me/DJwzcEph
# 77                          http://r.ebnd.de/r/qz=QKT
# 78  https://www.scottiugo.it/auto/usate/Opel/Insig...
# 79  https://twitter.com/tom_dlp/status/95013104981...
# 80                            https://buff.ly/2Emrdpl
# 81  https://twitter.com/ailol23/status/95043851076...
# 82  https://twitter.com/947144115753545728/status/...
# 83  https://twitter.com/i/web/status/9504394618123...
# 84  https://twitter.com/PMoreira80/status/95010156...
# 85  https://twitter.com/i/web/status/9504394617913...
# 86    http://jocee.jp/user/watwr/8f492b27ce56481d84aa
# 87                            https://fb.me/7j2qi5AZa
# 88  http://click.dtiserv2.com/Direct/9006999-6-195...
# 89  https://www.corbettreport.com/its-2018-time-to...
# 90                      http://youtu.be/NK8FU3Ma-Qk?a
# 91  https://twitter.com/i/web/status/9504394659898...
# 92  https://twitter.com/i/web/status/9504394659898...
# 93  https://twitter.com/i/web/status/9504394660024...
# 94  https://twitter.com/ellievhall/status/95043390...
# 95                             http://amzn.to/2Ekxodw
# 96  https://twitter.com/bahhbee/status/95040036551...
# 97  https://twitter.com/LaterCapitalism/status/949...
# 98                                    http://du3a.org
# 99  https://twitter.com/i/web/status/9504394659815...
#
#                        parsedURL           timestamp  hour
# 0                    youtube.com 2018-01-08 18:47:59    18
# 1                    twitter.com 2018-01-08 18:47:59    18
# 2                         bit.ly 2018-01-08 18:47:59    18
# 3                         goo.gl 2018-01-08 18:47:59    18
# 4                  instagram.com 2018-01-08 18:47:59    18
# 5                    twitter.com 2018-01-08 18:47:59    18
# 6                   alathkar.org 2018-01-08 18:47:59    18
# 7               open.spotify.com 2018-01-08 18:47:59    18
# 8                    twitter.com 2018-01-08 18:47:59    18
# 9                    twitter.com 2018-01-08 18:47:59    18
# 10                   twitter.com 2018-01-08 18:47:59    18
# 11                        goo.gl 2018-01-08 18:47:59    18
# 12                   twitter.com 2018-01-08 18:48:00    18
# 13                      du3a.org 2018-01-08 18:48:00    18
# 14           whounfollowedme.org 2018-01-08 18:48:00    18
# 15                        goo.gl 2018-01-08 18:48:00    18
# 16                      du3a.org 2018-01-08 18:48:00    18
# 17                   twitter.com 2018-01-08 18:48:00    18
# 18                   twitter.com 2018-01-08 18:48:00    18
# 19                   twitter.com 2018-01-08 18:48:00    18
# 20                     a.pgtb.me 2018-01-08 18:48:00    18
# 21                       vine.co 2018-01-08 18:48:00    18
# 22                   twitter.com 2018-01-08 18:48:00    18
# 23             ww.elbernabeu.com 2018-01-08 18:48:00    18
# 24  pianoforalltips.blogspot.com 2018-01-08 18:48:00    18
# 25         fashionglamtrends.com 2018-01-08 18:48:00    18
# 26                   tinyurl.com 2018-01-08 18:48:01    18
# 27                   twitter.com 2018-01-08 18:48:01    18
# 28                      du3a.org 2018-01-08 18:48:01    18
# 29                      du3a.org 2018-01-08 18:48:01    18
# ..                           ...                 ...   ...
# 70                   twitter.com 2018-01-08 18:49:59    18
# 71                   twitter.com 2018-01-08 18:49:59    18
# 72                   twitter.com 2018-01-08 18:49:59    18
# 73                   twitter.com 2018-01-08 18:50:00    18
# 74                       dlvr.it 2018-01-08 18:50:00    18
# 75                   twitter.com 2018-01-08 18:50:00    18
# 76                         fb.me 2018-01-08 18:50:00    18
# 77                     r.ebnd.de 2018-01-08 18:50:00    18
# 78                  scottiugo.it 2018-01-08 18:50:00    18
# 79                   twitter.com 2018-01-08 18:50:00    18
# 80                       buff.ly 2018-01-08 18:50:00    18
# 81                   twitter.com 2018-01-08 18:50:00    18
# 82                   twitter.com 2018-01-08 18:50:00    18
# 83                   twitter.com 2018-01-08 18:50:00    18
# 84                   twitter.com 2018-01-08 18:50:00    18
# 85                   twitter.com 2018-01-08 18:50:00    18
# 86                      jocee.jp 2018-01-08 18:50:01    18
# 87                         fb.me 2018-01-08 18:50:01    18
# 88            click.dtiserv2.com 2018-01-08 18:50:01    18
# 89             corbettreport.com 2018-01-08 18:50:01    18
# 90                      youtu.be 2018-01-08 18:50:01    18
# 91                   twitter.com 2018-01-08 18:50:01    18
# 92                   twitter.com 2018-01-08 18:50:01    18
# 93                   twitter.com 2018-01-08 18:50:01    18
# 94                   twitter.com 2018-01-08 18:50:01    18
# 95                       amzn.to 2018-01-08 18:50:01    18
# 96                   twitter.com 2018-01-08 18:50:01    18
# 97                   twitter.com 2018-01-08 18:50:01    18
# 98                      du3a.org 2018-01-08 18:50:01    18
# 99                   twitter.com 2018-01-08 18:50:01    18
#
# [100 rows x 4 columns]

# %%
# TEST - Run this cell to test your solution
cols = urlWithTimestampDF.columns
sample = urlWithTimestampDF.first()

dfTest("ET2-P-08-05-01", True, "URL" in cols and "parsedURL" in cols and "timestamp" in cols and "hour" in cols)
dfTest("ET2-P-08-05-02", 18, sample["hour"])

print("Tests passed!")
# Out:
# Tests passed!

# %% [markdown]
# ### Step 2: Calculate Trending URLs
#
# Create a DataFrame `urlTrendsDF` that looks at the top 10 hourly counts of domain names and includes the following columns:<br><br>
#
# * `hour`
# * `parsedURL`
# * `count`
#
# The result should sort `hour` in ascending order and `count` in descending order.

# %%
urlTrendsDF = urlWithTimestampDF.groupby('hour', 'parsedURL').count().orderBy(F.asc('hour'), F.desc('count'))

# %%
display(urlTrendsDF)
# Out:
#    hour      parsedURL  count
# 0    18    twitter.com    159
# 1    18         bit.ly     25
# 2    18          fb.me     17
# 3    18       youtu.be     16
# 4    18       du3a.org     15
# 5    18         goo.gl     12
# 6    18  instagram.com     10
# 7    18  curiouscat.me      6
# 8    18        dlvr.it      4
# 9    18    youtube.com      3

# %%
# TEST - Run this cell to test your solution
cols = urlTrendsDF.columns
sample = urlTrendsDF.first()

dfTest("ET2-P-08-06-01", True, "hour" in cols and "parsedURL" in cols and "count" in cols)
dfTest("ET2-P-08-06-02", 18, sample["hour"])
dfTest("ET2-P-08-06-03", "twitter.com", sample["parsedURL"])
dfTest("ET2-P-08-06-04", 159, sample["count"])

print("Tests passed!")
# Out:
# Tests passed!

# %% [markdown]
# ## Exercise 3: Join New Data
#
# Filter out bad users.

# %% [markdown]
# ### Step 1: Import Table of Bad Actors
#
# Create the DataFrame `badActorsDF`, a list of bad actors that sits in `s3a://data.intellinum.co/bootcamp/common/twitter/supplemental/badactors.parquet`.

# %%
# TODO
badActorPath = "s3a://data.intellinum.co/bootcamp/common/twitter/supplemental/badactors.parquet"
badActorsDF = spark.read.parquet(badActorPath)

# %%
display(badActorsDF)
print(badActorsDF.count())
# Out:
# 72

# %%
# TEST - Run this cell to test your solution
cols = badActorsDF.columns
sample = badActorsDF.first()

dfTest("ET2-P-08-07-01", True, "userID" in cols and "screenName" in cols)
dfTest("ET2-P-08-07-02", 4875602384, sample["userID"])
dfTest("ET2-P-08-07-03", "cris_silvag1", sample["screenName"])

print("Tests passed!")
# Out:
# Tests passed!

# %% [markdown]
# ### Step 2: Add a Column for Bad Actors
#
# Add a new column to `tweetDF` called `maliciousAcct` with `true` if the user is in `badActorsDF`.  Save the results to `tweetWithMaliciousDF`.  Remember to do a left join of the malicious accounts on `tweetDF`.

# %%
# TODO
tweetJoinedDF = tweetDF.join(F.broadcast(badActorsDF), tweetDF.user.id == badActorsDF.userID, 'left')

# %%
tweetJoinedDF.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- user: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- screen_name: string (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- friends_count: integer (nullable = true)
#  |    |-- followers_count: integer (nullable = true)
#  |    |-- description: string (nullable = true)
#  |-- entities: struct (nullable = true)
#  |    |-- hashtags: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- urls: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |-- lang: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- userID: long (nullable = true)
#  |-- screenName: string (nullable = true)

# %%
# tweetJoinedDF.first()
display(tweetJoinedDF, 100)
# Out:
#                    id                                               user  \
# 0  950438954272096257  (371607576, smileifyou_love, None, 473, 160, •...
# 1  950438954288914432  (732417055, bw198e18, None, 1641, 1285, 【期間限定】...
# 2  950438954276450305    (235927210, marlascigarette, None, 214, 223, △)
# 3  950438954280472576       (1564880654, rebaab_1326, None, 45, 0, None)
# 4  950438954288889856  (349070364, puskine, Kampala, Uganda, 5008, 49...
# 5  950438954280669184  (340482488, xNina_Beana, the land , 1130, 1646...
# 6  950438954276442113  (4354072997, gbfranca22, cpx da congo🔞, 252, 6...
# 7  950438954276478976  (738897225061912576, squeeqi, None, 213, 160, ...
# 8  950438954289033216          (273646363, iiib53, None, 631, 427, None)
# 9  950438954289033218     (1541143441, nappo_what, 🇫🇮🇺🇦, 297, 925, None)
#
#                                             entities lang  \
# 0                                           ([], [])   en
# 1                                    ([(diet,)], [])   ja
# 2                                           ([], [])   tr
# 3  ([(صاروخ_سعودي_يرعب_ايران,)], [(https://t.co/j...   ar
# 4                                           ([], [])   en
# 5                                           ([], [])   en
# 6                                           ([], [])   pt
# 7                                           ([], [])   en
# 8                                           ([], [])   ar
# 9                                           ([], [])   ru
#
#                                                 text  \
# 0  RT @TheTinaVasquez: Quick facts for the know-n...
# 1  【太ももを引きしめるエクササイズ】足あげ～１．うつぶせに寝る。２．片方の足先を床から10セン...
# 2  Ben bir beni bulup icine girip saklanirsam kim...
# 3  تواصل قالوا عن قطر المتحدث باسم الجيش الصهيوني...
# 4  *Before you argue about your dirty house someo...
# 5  RT @TippyLexx: Bruh you ever accidentally open...
# 6  RT @MorraoTudo2: A liberdade é só questão de t...
# 7                    I just want this all to be over
# 8  RT @Arab_original: للاسف قطاع كان ممكن حل ولا ...
# 9  RT @craneswordboi: блять мне так смешно от сло...
#
#                        created_at       userID screenName
# 0  Mon Jan 08 18:47:59 +0000 2018          NaN       None
# 1  Mon Jan 08 18:47:59 +0000 2018          NaN       None
# 2  Mon Jan 08 18:47:59 +0000 2018          NaN       None
# 3  Mon Jan 08 18:47:59 +0000 2018          NaN       None
# 4  Mon Jan 08 18:47:59 +0000 2018          NaN       None
# 5  Mon Jan 08 18:47:59 +0000 2018          NaN       None
# 6  Mon Jan 08 18:47:59 +0000 2018          NaN       None
# 7  Mon Jan 08 18:47:59 +0000 2018          NaN       None
# 8  Mon Jan 08 18:47:59 +0000 2018  273646363.0     iiib53
# 9  Mon Jan 08 18:47:59 +0000 2018          NaN       None

# %%
print(tweetJoinedDF.count(), tweetDF.count())
# Out:
# 1491 1491

# %%
tweetWithMaliciousDF = tweetJoinedDF.withColumn('maliciousAcct', F.when(F.col('userID').isNotNull(), True)\
                                               .otherwise(False))

# %%
display(tweetWithMaliciousDF)
# Out:
#                    id                                               user  \
# 0  950438954272096257  (371607576, smileifyou_love, None, 473, 160, •...
# 1  950438954288914432  (732417055, bw198e18, None, 1641, 1285, 【期間限定】...
# 2  950438954276450305    (235927210, marlascigarette, None, 214, 223, △)
# 3  950438954280472576       (1564880654, rebaab_1326, None, 45, 0, None)
# 4  950438954288889856  (349070364, puskine, Kampala, Uganda, 5008, 49...
# 5  950438954280669184  (340482488, xNina_Beana, the land , 1130, 1646...
# 6  950438954276442113  (4354072997, gbfranca22, cpx da congo🔞, 252, 6...
# 7  950438954276478976  (738897225061912576, squeeqi, None, 213, 160, ...
# 8  950438954289033216          (273646363, iiib53, None, 631, 427, None)
# 9  950438954289033218     (1541143441, nappo_what, 🇫🇮🇺🇦, 297, 925, None)
#
#                                             entities lang  \
# 0                                           ([], [])   en
# 1                                    ([(diet,)], [])   ja
# 2                                           ([], [])   tr
# 3  ([(صاروخ_سعودي_يرعب_ايران,)], [(https://t.co/j...   ar
# 4                                           ([], [])   en
# 5                                           ([], [])   en
# 6                                           ([], [])   pt
# 7                                           ([], [])   en
# 8                                           ([], [])   ar
# 9                                           ([], [])   ru
#
#                                                 text  \
# 0  RT @TheTinaVasquez: Quick facts for the know-n...
# 1  【太ももを引きしめるエクササイズ】足あげ～１．うつぶせに寝る。２．片方の足先を床から10セン...
# 2  Ben bir beni bulup icine girip saklanirsam kim...
# 3  تواصل قالوا عن قطر المتحدث باسم الجيش الصهيوني...
# 4  *Before you argue about your dirty house someo...
# 5  RT @TippyLexx: Bruh you ever accidentally open...
# 6  RT @MorraoTudo2: A liberdade é só questão de t...
# 7                    I just want this all to be over
# 8  RT @Arab_original: للاسف قطاع كان ممكن حل ولا ...
# 9  RT @craneswordboi: блять мне так смешно от сло...
#
#                        created_at       userID screenName  maliciousAcct
# 0  Mon Jan 08 18:47:59 +0000 2018          NaN       None          False
# 1  Mon Jan 08 18:47:59 +0000 2018          NaN       None          False
# 2  Mon Jan 08 18:47:59 +0000 2018          NaN       None          False
# 3  Mon Jan 08 18:47:59 +0000 2018          NaN       None          False
# 4  Mon Jan 08 18:47:59 +0000 2018          NaN       None          False
# 5  Mon Jan 08 18:47:59 +0000 2018          NaN       None          False
# 6  Mon Jan 08 18:47:59 +0000 2018          NaN       None          False
# 7  Mon Jan 08 18:47:59 +0000 2018          NaN       None          False
# 8  Mon Jan 08 18:47:59 +0000 2018  273646363.0     iiib53           True
# 9  Mon Jan 08 18:47:59 +0000 2018          NaN       None          False

# %%
# TEST - Run this cell to test your solution
cols = tweetWithMaliciousDF.columns
sample = tweetWithMaliciousDF.first()

dfTest("ET2-P-08-08-01", True, "maliciousAcct" in cols and "id" in cols)
dfTest("ET2-P-08-08-02", 950438954272096257, sample["id"])
dfTest("ET2-P-08-08-03", False, sample["maliciousAcct"])

print("Tests passed!")
# Out:
# Tests passed!

# %% [markdown]
# ## Exercise 4: Load Records
#
# Transform your two DataFrames to 4 partitions and save the results to the following endpoints:
#
# | DataFrame              | Endpoint                            |
# |:-----------------------|:------------------------------------|
# | `urlTrendsDF`          | `userhome + /tmp/urlTrends.parquet`            |
# | `tweetWithMaliciousDF` | `userhome + /tmp/tweetWithMaliciousDF.parquet` |

# %%
# TODO
YOUR_FIRST_NAME = 'rajeev'
userhome = f"s3a://temp.intellinum.co/{YOUR_FIRST_NAME}"
urlTrendsDF.repartition(4).write.mode('OVERWRITE').parquet(userhome+'/tmp/urlTrends.parquet')
tweetWithMaliciousDF.repartition(4).write.mode('OVERWRITE').parquet(userhome+'/tmp/tweetWithMaliciousDF.parquet')

# %%
# !aws s3 ls {userhome.replace('s3a','s3') + "/tmp/urlTrends.parquet"}/
# !aws s3 ls {userhome.replace('s3a','s3') + "/tmp/tweetWithMaliciousDF.parquet"}/
# Out:
# 2019-06-25 13:45:22          0 _SUCCESS
# 2019-06-25 13:45:21       1364 part-00000-f33cae13-09a1-4eec-a458-133cfaba4799-c000.snappy.parquet
# 2019-06-25 13:45:21       1360 part-00001-f33cae13-09a1-4eec-a458-133cfaba4799-c000.snappy.parquet
# 2019-06-25 13:45:21       1348 part-00002-f33cae13-09a1-4eec-a458-133cfaba4799-c000.snappy.parquet
# 2019-06-25 13:45:22       1466 part-00003-f33cae13-09a1-4eec-a458-133cfaba4799-c000.snappy.parquet
# 2019-06-25 13:45:25          0 _SUCCESS
# 2019-06-25 13:45:24      92076 part-00000-9b36ea02-c76c-4d78-86e7-55d101142c0b-c000.snappy.parquet
# 2019-06-25 13:45:24      88110 part-00001-9b36ea02-c76c-4d78-86e7-55d101142c0b-c000.snappy.parquet
# 2019-06-25 13:45:25      90022 part-00002-9b36ea02-c76c-4d78-86e7-55d101142c0b-c000.snappy.parquet
# 2019-06-25 13:45:25      87642 part-00003-9b36ea02-c76c-4d78-86e7-55d101142c0b-c000.snappy.parquet

# %%
# TEST - Run this cell to test your solution
urlTrendsDFTemp = spark.read.parquet(userhome + "/tmp/urlTrends.parquet")
tweetWithMaliciousDFTemp = spark.read.parquet(userhome + "/tmp/tweetWithMaliciousDF.parquet")

dfTest("ET2-P-08-09-01", 2, urlTrendsDFTemp.rdd.getNumPartitions())
dfTest("ET2-P-08-09-02", 2, tweetWithMaliciousDFTemp.rdd.getNumPartitions())

print("Tests passed!")
# Out:
# Tests passed!

# %% [markdown]
# ## IMPORTANT Next Steps
# * Please complete the <a href="https://docs.google.com/forms/d/e/1FAIpQLSd5whqoFBjNEEMvgwW5KRr-PeMyv6Lsczxk1p0es9s3IigEYQ/viewform?vc=0&c=0&w=1" target="_blank">short feedback survey</a>.  Your input is extremely important and shapes future course development.
# * Congratulations, you have completed ETL Part 2!

# %% [markdown]
# &copy; 2019 [Intellinum Analytics, Inc](http://www.intellinum.co). All rights reserved.<br/>
