# %%
sc.setLogLevel("ERROR")

# %%
lines = sc.textFile("test.txt")
words = lines.flatMap(lambda line : line.split(" "))

wordCounts = words.countByValue()

for word, count in wordCounts.items():
    print("{} : {}".format(word, count))
# Out:
# Jupyter : 1
# Notebook : 1
# Untitled : 1
# Last : 1
# Checkpoint: : 1
# 12 : 1
# minutes : 1
# ago : 1
# (autosaved) : 1
# Current : 1
# Kernel : 2
# Logo : 1
# Python : 1
# 3 : 2
#  : 474
# File : 1
# Edit : 1
# View : 1
# Insert : 1
# Cell : 1
# Widgets : 1
# Help : 1
# sc : 2
# SparkContext : 1
# Spark : 1
# UI : 1
# Version : 1
# v2.4.3 : 1
# Master : 1
# local[*] : 1
# AppName : 1
# PySparkShell : 1
# lines : 1
# = : 5
# sc.textFile('license.txt') : 1
# lines.count() : 2
# --------------------------------------------------------------------------- : 1
# Py4JJavaError : 1
# Traceback : 2
# (most : 2
# recent : 2
# call : 3
# last) : 2
# ~/spark/python/pyspark/sql/utils.py : 2
# in : 11
# deco(*a, : 2
# **kw) : 3
# 62 : 1
# try: : 1
# ---> : 2
# 63 : 1
# return : 6
# f(*a, : 1
# 64 : 1
# except : 1
# py4j.protocol.Py4JJavaError : 1
# as : 2
# e: : 1
# ~/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py : 1
# get_return_value(answer, : 1
# gateway_client, : 1
# target_id, : 1
# name) : 1
# 327 : 1
# "An : 1
# error : 2
# occurred : 2
# while : 2
# calling : 2
# {0}{1}{2}.\n". : 1
# --> : 3
# 328 : 1
# format(target_id, : 1
# ".", : 1
# name), : 1
# value) : 1
# 329 : 1
# else: : 1
# Py4JJavaError: : 1
# An : 1
# z:org.apache.spark.api.python.PythonRDD.collectAndServe. : 1
# : : 1
# java.lang.IllegalArgumentException: : 1
# Unsupported : 1
# class : 2
# file : 2
# major : 2
# version : 2
# 55 : 1
# 	at : 45
# org.apache.xbean.asm6.ClassReader.<init>(ClassReader.java:166) : 1
# org.apache.xbean.asm6.ClassReader.<init>(ClassReader.java:148) : 1
# org.apache.xbean.asm6.ClassReader.<init>(ClassReader.java:136) : 1
# org.apache.xbean.asm6.ClassReader.<init>(ClassReader.java:237) : 1
# org.apache.spark.util.ClosureCleaner$.getClassReader(ClosureCleaner.scala:49) : 1
# org.apache.spark.util.FieldAccessFinder$$anon$3$$anonfun$visitMethodInsn$2.apply(ClosureCleaner.scala:517) : 1
# org.apache.spark.util.FieldAccessFinder$$anon$3$$anonfun$visitMethodInsn$2.apply(ClosureCleaner.scala:500) : 1
# scala.collection.TraversableLike$WithFilter$$anonfun$foreach$1.apply(TraversableLike.scala:733) : 1
# scala.collection.mutable.HashMap$$anon$1$$anonfun$foreach$2.apply(HashMap.scala:134) : 2
# scala.collection.mutable.HashTable$class.foreachEntry(HashTable.scala:236) : 1
# scala.collection.mutable.HashMap.foreachEntry(HashMap.scala:40) : 1
# scala.collection.mutable.HashMap$$anon$1.foreach(HashMap.scala:134) : 1
# scala.collection.TraversableLike$WithFilter.foreach(TraversableLike.scala:732) : 1
# org.apache.spark.util.FieldAccessFinder$$anon$3.visitMethodInsn(ClosureCleaner.scala:500) : 1
# org.apache.xbean.asm6.ClassReader.readCode(ClassReader.java:2175) : 1
# org.apache.xbean.asm6.ClassReader.readMethod(ClassReader.java:1238) : 1
# org.apache.xbean.asm6.ClassReader.accept(ClassReader.java:631) : 1
# org.apache.xbean.asm6.ClassReader.accept(ClassReader.java:355) : 1
# org.apache.spark.util.ClosureCleaner$$anonfun$org$apache$spark$util$ClosureCleaner$$clean$14.apply(ClosureCleaner.scala:307) : 1
# org.apache.spark.util.ClosureCleaner$$anonfun$org$apache$spark$util$ClosureCleaner$$clean$14.apply(ClosureCleaner.scala:306) : 1
# scala.collection.immutable.List.foreach(List.scala:392) : 1
# org.apache.spark.util.ClosureCleaner$.org$apache$spark$util$ClosureCleaner$$clean(ClosureCleaner.scala:306) : 1
# org.apache.spark.util.ClosureCleaner$.clean(ClosureCleaner.scala:162) : 1
# org.apache.spark.SparkContext.clean(SparkContext.scala:2326) : 1
# org.apache.spark.SparkContext.runJob(SparkContext.scala:2100) : 1
# org.apache.spark.SparkContext.runJob(SparkContext.scala:2126) : 1
# org.apache.spark.rdd.RDD$$anonfun$collect$1.apply(RDD.scala:945) : 1
# org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151) : 1
# org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112) : 1
# org.apache.spark.rdd.RDD.withScope(RDD.scala:363) : 1
# org.apache.spark.rdd.RDD.collect(RDD.scala:944) : 1
# org.apache.spark.api.python.PythonRDD$.collectAndServe(PythonRDD.scala:166) : 1
# org.apache.spark.api.python.PythonRDD.collectAndServe(PythonRDD.scala) : 1
# java.base/jdk.internal.reflect.NativeMethodAccessorImpl.invoke0(Native : 1
# Method) : 1
# java.base/jdk.internal.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62) : 1
# java.base/jdk.internal.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43) : 1
# java.base/java.lang.reflect.Method.invoke(Method.java:566) : 1
# py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244) : 1
# py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357) : 1
# py4j.Gateway.invoke(Gateway.java:282) : 1
# py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132) : 1
# py4j.commands.CallCommand.execute(CallCommand.java:79) : 1
# py4j.GatewayConnection.run(GatewayConnection.java:238) : 1
# java.base/java.lang.Thread.run(Thread.java:834) : 1
# During : 1
# handling : 1
# of : 1
# the : 3
# above : 1
# exception, : 1
# another : 1
# exception : 1
# occurred: : 1
# IllegalArgumentException : 1
# <ipython-input-12-c800bb714bd8> : 1
# <module> : 1
# ----> : 1
# 1 : 1
# ~/spark/python/pyspark/rdd.py : 4
# count(self) : 1
# 1053 : 1
# 1054 : 1
# """ : 3
# -> : 3
# 1055 : 1
# self.mapPartitions(lambda : 2
# i: : 1
# [sum(1 : 1
# for : 2
# _ : 1
# i)]).sum() : 1
# 1056 : 1
# 1057 : 1
# def : 2
# stats(self): : 1
# sum(self) : 1
# 1044 : 1
# 6.0 : 1
# 1045 : 1
# 1046 : 1
# x: : 1
# [sum(x)]).fold(0, : 1
# operator.add) : 1
# 1047 : 1
# 1048 : 1
# count(self): : 1
# fold(self, : 1
# zeroValue, : 1
# op) : 1
# 915 : 1
# # : 2
# zeroValue : 1
# provided : 2
# to : 2
# each : 1
# partition : 1
# is : 1
# unique : 1
# from : 1
# one : 1
# 916 : 1
# final : 1
# reduce : 1
# 917 : 1
# vals : 1
# self.mapPartitions(func).collect() : 1
# 918 : 1
# reduce(op, : 1
# vals, : 1
# zeroValue) : 1
# 919 : 1
# collect(self) : 1
# 814 : 1
# 815 : 1
# with : 1
# SCCallSiteSync(self.context) : 1
# css: : 1
# 816 : 1
# sock_info : 1
# self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd()) : 1
# 817 : 1
# list(_load_from_socket(sock_info, : 1
# self._jrdd_deserializer)) : 1
# 818 : 1
# ~/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py : 1
# __call__(self, : 1
# *args) : 1
# 1255 : 1
# answer : 1
# self.gateway_client.send_command(command) : 1
# 1256 : 1
# return_value : 1
# get_return_value( : 1
# 1257 : 1
# answer, : 1
# self.gateway_client, : 1
# self.target_id, : 1
# self.name) : 1
# 1258 : 1
# 1259 : 1
# temp_arg : 1
# temp_args: : 1
# 77 : 1
# raise : 3
# QueryExecutionException(s.split(': : 1
# ', : 2
# 1)[1], : 2
# stackTrace) : 2
# 78 : 1
# if : 1
# s.startswith('java.lang.IllegalArgumentException: : 1
# '): : 1
# 79 : 1
# IllegalArgumentException(s.split(': : 1
# 80 : 1
# 81 : 1
# deco : 1
# IllegalArgumentException: : 1
# 'Unsupported : 1
# 55' : 1
# ​ : 1
